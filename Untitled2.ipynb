# %% [markdown]
# <a href="https://colab.research.google.com/github/bintangsagale/PVCK-Genap2-20-21/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Cristiano_Ronaldo_2018.jpg/400px-Cristiano_Ronaldo_2018.jpg?20210714170018",
        "https://bantenhariini.id/wp-content/uploads/2022/01/puan-maharani.jpg",
        "https://asset.kompas.com/crops/gPeOWFA3DUFaCuYq0NhrzsdXB7E=/0x0:779x519/750x500/data/photo/2021/10/15/61698c7aece86.jpg"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F57CEDA38E0>
# <PIL.Image.Image image mode=RGB size=672x194 at 0x7F57CBE7BB20>
# <PIL.Image.Image image mode=RGB size=750x250 at 0x7F57CBE66D90>

# %%
import numpy as np
import pandas as pd 
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Cristiano_Ronaldo_2018.jpg/400px-Cristiano_Ronaldo_2018.jpg?20210714170018",
        "https://bantenhariini.id/wp-content/uploads/2022/01/puan-maharani.jpg",
        "https://asset.kompas.com/crops/gPeOWFA3DUFaCuYq0NhrzsdXB7E=/0x0:779x519/750x500/data/photo/2021/10/15/61698c7aece86.jpg"]

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: Tinggi X Lebar = ",tinggi," x ", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: Tinggi X Lebar =  250  x  375
# <PIL.Image.Image image mode=RGB size=375x250 at 0x7F57C81B1640>

# %%
import numpy as np
import pandas as pd 
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Cristiano_Ronaldo_2018.jpg/400px-Cristiano_Ronaldo_2018.jpg?20210714170018",
        "https://bantenhariini.id/wp-content/uploads/2022/01/puan-maharani.jpg",
        "https://asset.kompas.com/crops/gPeOWFA3DUFaCuYq0NhrzsdXB7E=/0x0:779x519/750x500/data/photo/2021/10/15/61698c7aece86.jpg"]

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250 at 0x7F57C81C8130>

# %% [markdown]
# TUGAS RUMAH

# %% [markdown]
# vertikal horizontal

# %%
import numpy as np
import pandas as pd 
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Cristiano_Ronaldo_2018.jpg/400px-Cristiano_Ronaldo_2018.jpg?20210714170018",
        "https://bantenhariini.id/wp-content/uploads/2022/01/puan-maharani.jpg",
        "https://asset.kompas.com/crops/gPeOWFA3DUFaCuYq0NhrzsdXB7E=/0x0:779x519/750x500/data/photo/2021/10/15/61698c7aece86.jpg"]

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]
  
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250 at 0x7F57C81C8700>

# %% [markdown]
# Menyilang

# %%
import numpy as np
import pandas as pd 
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Cristiano_Ronaldo_2018.jpg/400px-Cristiano_Ronaldo_2018.jpg?20210714170018",
        "https://bantenhariini.id/wp-content/uploads/2022/01/puan-maharani.jpg",
        "https://asset.kompas.com/crops/gPeOWFA3DUFaCuYq0NhrzsdXB7E=/0x0:779x519/750x500/data/photo/2021/10/15/61698c7aece86.jpg"]

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

thickness = 1
color = (255, 255, 255)

image_3 = cv.line(image_3, (0,0), (lebar,tinggi), color, thickness)
image_3 = cv.line(image_3, (lebar,0), (0,tinggi), color, thickness)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250 at 0x7F57C81B1640>

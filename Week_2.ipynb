# %% [markdown]
# <a href="https://colab.research.google.com/github/bintangsagale/PVCK-Genap2-20-21/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRAKTIKUM

# %%
from google.colab import drive

# Accessing my Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')
plt.imshow(img) #perhatikan hasilnya adalah citra dgn channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))   #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hallo',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# TUGAS

# %%
#green-blue
import cv2
import numpy as np

img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')
img[:,:,2] = np.zeros([img.shape[0], img.shape[1]])
plt.imshow(img)

# %%
#red-green
import cv2
import numpy as np

img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')
img[:,:,0] = np.zeros([img.shape[0], img.shape[1]])
plt.imshow(img)

# %%
#baris ke10-11, kolom ke10-100
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')
plt.imshow(img[10:100,10:100])

# %%
#bairs ke5-30, semua kolom, channel Green
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')
plt.imshow(img[5:30], cmap='Greens')

# %%
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')

cv.rectangle(img,pt1=(1500,400),pt2=(1600,1100),color=(0,255,255),thickness=5)
cv.rectangle(img,pt1=(300,1000),pt2=(500,800),color=(255,255,0),thickness=5)
cv.rectangle(img,pt1=(750,500),pt2=(1750,800),color=(0,255,0),thickness=5)
cv.rectangle(img,pt1=(600,200),pt2=(1250,1000),color=(255,0,0),thickness=5)
cv.rectangle(img,pt1=(384,0),pt2=(510,150),color=(0,0,255),thickness=5)

plt.imshow(img)

# %%
img = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')
cv.rectangle(img,pt1=(800,300),pt2=(1250,750),color=(0,255,0),thickness=5)
cv.circle(img,center=(1000,500),radius=200,color=(255,0,0),thickness=5)
plt.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/61ab9370d9dc7.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

cv.rectangle(img,pt1=(0,1200),pt2=(250,1350),color=(0,255,0),thickness=5)
plt.imshow(img)
